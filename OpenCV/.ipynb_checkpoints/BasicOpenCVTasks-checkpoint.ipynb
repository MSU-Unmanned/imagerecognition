# %%
# ! pip install opencv-python
# ! pip install numpy
# ! pip install matplotlib
import cv2
import numpy
import matplotlib.pyplot as plt

# %%
ex_img = cv2.imread('opencv-image.jpg', cv2.IMREAD_COLOR) #imports image
ex_img_grey = cv2.imread(r'opencv-image.jpg', cv2.IMREAD_GRAYSCALE) #imports image in grayscale

#Usinv cv2 - NOT WORKING, KERNEL IS DYING
# cv2.imshow('image', ex_img) #makes a gui for the image
# cv2.waitKey(0) #Keeps window on screen
# cv2.destroyAllWindows() #Gets rid of gui

#Using matplotlib
plt.imshow(ex_img) #Shows image

# %%
plt.imshow(ex_img_grey)
